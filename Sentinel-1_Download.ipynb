# %%
import ee
# Out:
# ---------------------------------------------------------------------------
# DistributionNotFound                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16856/2985164896.py in <module>
# ----> 1 import ee
#
# ~\anaconda3\envs\nanok\lib\site-packages\ee\__init__.py in <module>
#      15 import six
#      16
# ---> 17 from . import batch
#      18 from . import data
#      19 from . import deserializer
#
# ~\anaconda3\envs\nanok\lib\site-packages\ee\batch.py in <module>
#      13 import six
#      14
# ---> 15 from . import _cloud_api_utils
#      16 from . import data
#      17 from . import ee_exception
#
# ~\anaconda3\envs\nanok\lib\site-packages\ee\_cloud_api_utils.py in <module>
#      21 from google_auth_httplib2 import AuthorizedHttp
#      22 from google_auth_httplib2 import Request
# ---> 23 from googleapiclient import discovery
#      24 from googleapiclient import http
#      25 from googleapiclient import model
#
# ...
